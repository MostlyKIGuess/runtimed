# %%
import numpy

# %% [markdown]
# A random array

# %% [raw]
# A random array

# %% [markdown]
# ## My Heading

# %%
a = numpy.random.rand(100)

# %%
print "ünîcødé"
# Out:
# <array a>
# <array a>
# frame 0
# frame 1
# frame 2
# bar
# bar
